# %% [markdown]
# # Análisis Climático
#
# En esta libreta analizamos datos climáticos a partir de un archivo EPW.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Ejemplo: aquí cargaríamos el archivo EPW y analizaríamos los datos climáticos")

# %% [markdown]
# ## Temperatura
#
# Análisis de temperatura de bulbo seco a lo largo del año.
