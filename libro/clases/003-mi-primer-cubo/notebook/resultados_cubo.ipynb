# %% [markdown]
# # Resultados: Mi Primer Cubo
#
# En esta libreta analizamos los resultados de la simulación energética del cubo.

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Ejemplo: aquí cargaríamos los resultados de EnergyPlus y los visualizaríamos")

# %% [markdown]
# ## Demanda energética
#
# Gráfica de demanda de calefacción y enfriamiento mensual.
